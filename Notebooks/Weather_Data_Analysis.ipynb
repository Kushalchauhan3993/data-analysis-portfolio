# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
df = pd.read_csv("GlobalWeatherRepository.csv")

df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  wind_mph  wind_kph  wind_degree  \
# 0                    79.8  Partly Cloudy       8.3      13.3          338
# ...

# %%
df.shape
# Out:
# (127646, 41)

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
df['last_updated'] = pd.to_datetime(df['last_updated'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127646 entries, 0 to 127645
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   country                       127646 non-null  object
#  1   location_name                 127646 non-null  object
#  2   latitude                      127646 non-null  float64
#  3   longitude                     127646 non-null  float64
#  4   timezone                      127646 non-null  object
#  5   last_updated_epoch            127646 non-null  int64
#  6   last_updated                  127646 non-null  object
#  7   temperature_celsius           127646 non-null  float64
#  8   temperature_fahrenheit        127646 non-null  float64
#  9   condition_text                127646 non-null  object
#  10  wind_mph                      127646 non-null  float64
#  11  wind_kph                      127646 non-null  float64
# ...

# %%
df.describe()
# Out:
#             latitude      longitude  last_updated_epoch  temperature_celsius  \
# count  127646.000000  127646.000000        1.276460e+05        127646.000000
# mean       19.198346      21.985205        1.744252e+09            21.485175
# std        24.424259      65.793370        1.638609e+07             9.659990
# min       -41.300000    -175.200000        1.715849e+09           -29.800000
# 25%         3.750000      -6.836100        1.730107e+09            16.200000
# 50%        17.250000      23.240000        1.744276e+09            24.100000
# 75%        40.400000      50.580000        1.758441e+09            28.000000
# max        64.150000     179.220000        1.772607e+09            49.200000
#
#        temperature_fahrenheit       wind_mph       wind_kph    wind_degree  \
# count           127646.000000  127646.000000  127646.000000  127646.000000
# mean                70.675088       8.053645      12.964678     169.134199
# ...

# %%
df.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df['year'] = df['last_updated'].dt.year
df['month'] = df['last_updated'].dt.month
df['day'] = df['last_updated'].dt.day

# %%
df['season'] = df['month'] % 12 // 3 + 1

# %%
season_map = {1:'Winter',2:'Spring',3:'Summer',4:'Autumn'}

df['season'] = df['season'].map(season_map)

# %%
yearly_temp = df.groupby('year')['temperature_celsius'].mean()

yearly_temp
# Out:
# year
# 2024    23.611792
# 2025    21.188689
# 2026    15.400182
# Name: temperature_celsius, dtype: float64

# %%
plt.figure(figsize=(10,6))
yearly_temp.plot()
plt.title("Average Temperature Trend")
plt.xlabel("Year")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
df['last_updated'] = pd.to_datetime(df['last_updated'])

df['month'] = df['last_updated'].dt.month

# %%
df['season'] = df['month'] % 12 // 3 + 1
season_map = {1:'Winter',2:'Spring',3:'Summer',4:'Autumn'}
df['season'] = df['season'].map(season_map)

# %%
df[['month','season']].head()
# Out:
#    month  season
# 0      5  Spring
# 1      5  Spring
# 2      5  Spring
# 3      5  Spring
# 4      5  Spring

# %%
season_temp = df.groupby('season')['temperature_celsius'].mean()

season_temp
# Out:
# season
# Autumn    21.584803
# Spring    22.097518
# Summer    25.822884
# Winter    16.595733
# Name: temperature_celsius, dtype: float64

# %%
plt.figure(figsize=(8,5))
season_temp.plot(kind='bar')
plt.title("Average Temperature by Season")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination',
#        'year', 'month', 'day', 'season'],
#       dtype='object')

# %%
rainfall = df['precip_mm']

rainfall.describe()
# Out:
# count    127646.000000
# mean          0.135958
# std           0.567664
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.030000
# max          42.240000
# Name: precip_mm, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df['precip_mm'], bins=30)
plt.title("Rainfall Distribution")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Frequency")
plt.show()

# %%
extreme_hot = df[df['temperature_celsius'] > 40]

extreme_cold = df[df['temperature_celsius'] < 0]

print("Extreme Hot Events:", len(extreme_hot))
print("Extreme Cold Events:", len(extreme_cold))
# Out:
# Extreme Hot Events: 1228
# Extreme Cold Events: 3484

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['temperature_celsius'], bins=30)
plt.title("Temperature Distribution")
plt.xlabel("Temperature (°C)")
plt.show()

# %%
plt.figure(figsize=(8,5))
season_temp.plot(kind='bar')
plt.title("Average Temperature by Season")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
plt.figure(figsize=(8,5))
season_temp.plot(kind='bar')
plt.title("Average Temperature by Season")
plt.ylabel("Temperature")
plt.show()

# %%
plt.figure(figsize=(8,5))
season_temp.plot(kind='bar')
plt.title("Average Temperature by Season")
plt.ylabel("Temperature")
plt.show()

# %%
plt.figure(figsize=(10,7))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Weather Data Correlation Matrix")
plt.show()

# %% [markdown]
# Key Findings:
#
# -Temperature shows seasonal variation across the year
# -Summer seasons have the highest average temperature
# -Rainfall distribution shows occasional heavy precipitation events
# -Extreme weather events occur during peak seasonal changes

# %% [markdown]
# Recommendations:
#
# -Improve weather forecasting models for extreme weather events
# -Use historical weather trends for agricultural planning
# -Implement early warning systems for heavy rainfall
# -Monitor seasonal climate changes for long-term planning
